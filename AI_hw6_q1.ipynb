# %% [markdown]
# <a href="https://colab.research.google.com/github/shoumyasingh/Artificial_Intelligence_python/blob/main/AI_hw6_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install hmmlearn

import numpy as np
from hmmlearn import hmm

trans = ["B1", "B2", "B3"]
n_states = len(trans)   # = 3

emission = ["red", "green","yellow"]
n_emissions = len(emission)    # = 3

start_probability = np.array([0.4, 0.35, 0.25])

transition_probability = np.array([
  [0.3, 0.2, 0.5],
  [0.1, 0.3, 0.6],
  [0.7, 0.25, 0.05]
])

emission_probability = np.array([
  [0.8, 0.1, 0.1],
  [0.2, 0.4, 0.4],
  [0.15, 0.25, 0.6]
])

model = hmm.MultinomialHMM(n_components=n_states) 
# MultinomialHMM: observation distribution in Multinomial
model.startprob_=start_probability
model.transmat_=transition_probability
model.emissionprob_=emission_probability

seen = np.array([[0,0,2,1,2]]).T       
 # 0: red;     1: green     2:yellow   => red red yellow green yellow
logprob, box = model.decode(seen, algorithm="viterbi")
seen = [0,0,2,1,2]
print("The color of candy is order by:", ", ".join(map(lambda x: observations[x], seen)))
print("The candy bottle is order by:", ", ".join(map(lambda x: states[x], box)))

seen = np.array([[0,0,2,1,2]]).T 
box2 = model.predict(seen)      # "viterbi" of HMM (Hidden Markov Model)
seen = [0,0,2,1,2]
print("The color of candy is order by:", ", ".join(map(lambda x: observations[x], seen)))
print("The candy bottle is order by :", ", ".join(map(lambda x: states[x], box2)))

seen = np.array([[0,0,2,1,2]]).T                  # P(rrygy) = ?

print(model.score(seen))     
   # ln(P(red*red*yellow*green*yellow)) = -5.342304036552551   
   # P(rrygy) = exp(-5.342304036552551)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hmmlearn in /usr/local/lib/python3.7/dist-packages (0.2.7)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (1.7.3)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.16 in /usr/local/lib/python3.7/dist-packages (from hmmlearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.16->hmmlearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.16->hmmlearn) (3.1.0)
# The color of candy is order by: red, red, Yellow, green, Yellow
# The candy bottle is order by: box 1, box 1, box3, box 2, box3
# The color of candy is order by: red, red, Yellow, green, Yellow
# The candy bottle is order by : box 1, box 1, box3, box 2, box3
# -5.342304036552551
